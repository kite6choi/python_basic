# %% [markdown]
# # 파이썬으로 글자를 출력하기

# %%
print("Hello")

# %%
print('Good day!')

# %%
print("한글도 쓸 수 있어요.")

# %% [markdown]
# ## 문자열 연산

# %%
print("Hello, " + "World!")

# %%
print("내 이름은 " + "홍길동" + "입니다.")

# %%
print("*" * 10)

# %% [markdown]
# ## 문자열 값을 가지는 변수

# %%
name = "홍길동"
print("내 이름은 " + name + "입니다.")

# %%
print(123+123)

# %%
print("123"+"123")

# %%
print( str(123) + str(123) )

# %%
mark = "$"
n = 20
print(mark + " 기호를 " + str(n) + "번 출력합니다.")
print(mark * n)
