# %% [markdown]
# # 1.1 자료형(정수, 실수, 논리형)

# %% [markdown]
# ## 정수와 실수 자료형

# %%
a = 25
print(a)

# %%
b = 12
b

# %%
c = 12.5
c

# %% [markdown]
# ## 논리자료형(bool 형)

# %%
10 > 20

# %%
d = 10 > 20
d

# %%
d + 2

# %%
e = 20 > 10
e

# %%
e + 2

# %%
not e
